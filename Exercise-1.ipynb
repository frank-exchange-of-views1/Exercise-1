# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ice_cream_rating = 9

# %%
sleep_rating = 7

# %%
first_name = 'Scott'
last_name = 'Maislin'
name = first_name + ' ' + last_name

# %%
happiness_rating = (ice_cream_rating + sleep_rating) / 2

# %%
def type_lister(input_list):
  for item in input_list:
    print(type(item))

variable_list = [ice_cream_rating, sleep_rating, first_name, last_name, happiness_rating]

type_lister(variable_list)
# Out:
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'float'>

# %%
print(f"""hi my name is {name} and I give eating ice cream a score of {ice_cream_rating} out of 10!
\n my sleeping enjoyment rating is {sleep_rating}/10! \n Based on the factors above, my happiness rating is {ice_cream_rating*sleep_rating/10} out of 10 or 72%!
      """)
# Out:
# hi my name is Scott Maislin and I give eating ice cream a score of 9 out of 10!
#
#  my sleeping enjoyment rating is 7/10!
#  Based on the factors above, my happiness rating is 6.3 out of 10 or 72%!

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/Exercise-1"
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/Colab Notebooks/Exercise-1'
# /content
